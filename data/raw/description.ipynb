# %% [markdown]
# # fasta
# https://www.predictioncenter.org/download_area/CASP16/extra_experiments/pharma_ligands/
#
# * L1000: https://www.uniprot.org/uniprotkb/P23946
# * L3000: https://www.uniprot.org/uniprotkb/Q13822
#
# Download -> ⌘+S

# %% [markdown]
# # affinity
#
# https://www.predictioncenter.org/download_area/CASP16/extra_experiments/pharma_ligands/
